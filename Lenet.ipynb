# %%
from keras import layers 
from keras import models
from keras.models import Model 
model = models.Sequential()
model.add(layers.Conv2D(6, (5, 5), activation='relu', input_shape=(28, 28, 1),name="cov_1")) 
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(16, (5, 5), activation='relu')) 
model.add(layers.MaxPooling2D((2, 2)))
##model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(120, activation='relu'))
model.add(layers.Dense(84, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

# %% [markdown]
# the structure of lenet
# ![lenet-2.png](attachment:lenet-2.png)

# %%
from keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images.reshape((60000, 28, 28, 1))
train_images = train_images.astype('float32') / 255
test_images = test_images.reshape((10000, 28, 28, 1))
test_images = test_images.astype('float32') / 255
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)
model.compile(optimizer='rmsprop',
 loss='categorical_crossentropy',
 metrics=['accuracy'])
model.fit(train_images, train_labels, epochs=5, batch_size=64)
# Out:
# Epoch 1/5
# 938/938 [==============================] - 10s 6ms/step - loss: 0.2131 - accuracy: 0.9342
# Epoch 2/5
# 938/938 [==============================] - 5s 6ms/step - loss: 0.0655 - accuracy: 0.9795
# Epoch 3/5
# 938/938 [==============================] - 5s 6ms/step - loss: 0.0473 - accuracy: 0.9848
# Epoch 4/5
# 938/938 [==============================] - 6s 6ms/step - loss: 0.0372 - accuracy: 0.9883
# Epoch 5/5
# 938/938 [==============================] - 6s 6ms/step - loss: 0.0309 - accuracy: 0.9905

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
test_loss
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0373 - accuracy: 0.9881
# 0.03728843852877617
